# %% [markdown]
# ---
# # Import libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Model, layers
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
# 2023-06-20 14:32:10.289715: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# ---
# # Load GPU

# %%
# !nvidia-smi
# Out:
# Tue Jun 20 14:32:15 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.76       Driver Version: 515.76       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:B3:00.0  On |                  N/A |
# | 18%   45C    P8    13W / 215W |    649MiB /  8192MiB |      4%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1076      G   /usr/lib/xorg/Xorg                 18MiB |
# |    0   N/A  N/A      1197      G   /usr/bin/gnome-shell               70MiB |
# |    0   N/A  N/A      1407      G   /usr/lib/xorg/Xorg                225MiB |
# |    0   N/A  N/A      1519      G   /usr/bin/gnome-shell               35MiB |
# |    0   N/A  N/A      5021      G   /usr/lib/firefox/firefox          274MiB |
# |    0   N/A  N/A     20622      G   ...veSuggestionsOnlyOnDemand        2MiB |
# |    0   N/A  N/A     31722      G   ...veSuggestionsOnlyOnDemand        2MiB |
# |    0   N/A  N/A     31765      G   ...veSuggestionsOnlyOnDemand        2MiB |
# |    0   N/A  N/A     31777      G   ...veSuggestionsOnlyOnDemand        2MiB |
# |    0   N/A  N/A     31789      G   ...veSuggestionsOnlyOnDemand        2MiB |
# +-----------------------------------------------------------------------------+

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"]="0"
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)
# Out:
# 2023-06-20 14:32:15.480082: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-06-20 14:32:15.482557: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-06-20 14:32:15.543026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:b3:00.0 name: NVIDIA GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2023-06-20 14:32:15.543120: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-20 14:32:15.553688: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-06-20 14:32:15.553860: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-06-20 14:32:15.559240: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-06-20 14:32:15.561357: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-06-20 14:32:15.567833: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-06-20 14:32:15.570478: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-06-20 14:32:15.580218: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-06-20 14:32:15.580984: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %% [markdown]
# ---
# # Test Convolutional layer and Max Pooling layer

# %%
def convolution_layer_test(filters, kernel_size, s=1, p='valid', input_size=[1, 64, 64, 3]):
    inputs = tf.random.normal(input_size) # sampling from normal distribution
    print('input size: ', inputs.shape)
    conv = tf.keras.layers.Conv2D(filters, kernel_size, strides=s, padding=p)
    outputs = conv(inputs)
    print('output size: ', outputs.shape)

# %%
def pooling_layer_test(pool_size, s=1, p='valid', input_size=[1, 64, 64, 3]):
    inputs = tf.random.normal(input_size) # sampling from normal distribution
    print('input size: ', inputs.shape)
    pool = tf.keras.layers.MaxPool2D(pool_size, strides=s, padding=p)
    outputs = pool(inputs)
    print('output size: ', outputs.shape)

# %%
convolution_layer_test(10, 11, s=6, p='same', input_size=[1, 128, 128, 3])
# Out:
# 2023-06-20 14:32:18.668394: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-20 14:32:18.669159: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-06-20 14:32:18.669840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:b3:00.0 name: NVIDIA GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2023-06-20 14:32:18.669927: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-20 14:32:18.669994: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-06-20 14:32:18.670013: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-06-20 14:32:18.670032: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-06-20 14:32:18.670050: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-06-20 14:32:18.670069: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-06-20 14:32:18.670087: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-06-20 14:32:18.670125: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-06-20 14:32:18.670704: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2023-06-20 14:32:18.670758: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-20 14:32:19.291309: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-06-20 14:32:19.291344: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2023-06-20 14:32:19.291351: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2023-06-20 14:32:19.292245: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6647 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080, pci bus id: 0000:b3:00.0, compute capability: 7.5)
# 2023-06-20 14:32:19.326354: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# input size:  (1, 128, 128, 3)
# 2023-06-20 14:32:20.601515: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2023-06-20 14:32:20.683387: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-06-20 14:32:21.102796: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# output size:  (1, 22, 22, 10)

# %%
convolution_layer_test(10, 3)
# Out:
# input size:  (1, 64, 64, 3)
# output size:  (1, 62, 62, 10)

# %%
convolution_layer_test(100, 3)
# Out:
# input size:  (1, 64, 64, 3)
# output size:  (1, 62, 62, 100)

# %%
convolution_layer_test(100, 3, p='same')
# Out:
# input size:  (1, 64, 64, 3)
# output size:  (1, 64, 64, 100)

# %%
convolution_layer_test(100, 3, s=3, p='same')
"""
kernel_size = 3, stride = 1, padding = 1 -> input과 output의 크기가 같다.
kernel_size = 3, stride = 2, padding = 1 -> output의 row, col = input의 row, col의 절반
"""
# Out:
# input size:  (1, 64, 64, 3)
# output size:  (1, 22, 22, 100)
# '\nkernel_size = 3, stride = 1, padding = 1 -> input과 output의 크기가 같다.\nkernel_size = 3, stride = 2, padding = 1 -> output의 row, col = input의 row, col의 절반\n'

# %%
pooling_layer_test(2)

"""
kernel = (2, 2)
stride = 2
padding = 0

kernel = (3,3)
stride = 2
padeding = 1

"""
# Out:
# input size:  (1, 64, 64, 3)
# output size:  (1, 63, 63, 3)

# %%
pooling_layer_test(2, p='same')
# Out:
# input size:  (1, 64, 64, 3)
# output size:  (1, 64, 64, 3)

# %% [markdown]
# ---
# # CNN for MNIST

# %%
(x_trainval, y_trainval), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(type(x_trainval), x_trainval.shape)
print(type(y_trainval), y_trainval.shape)

x_train, x_valid, y_train, y_valid = train_test_split(x_trainval, y_trainval, test_size= 1/6, shuffle=True, stratify = y_trainval, random_state=34)
print(type(x_train), x_train.shape)
print(type(y_train), y_train.shape)
# Out:
# <class 'numpy.ndarray'> (60000, 28, 28)
# <class 'numpy.ndarray'> (60000,)
# <class 'numpy.ndarray'> (50000, 28, 28)
# <class 'numpy.ndarray'> (50000,)

# %%
plt.imshow(x_train[0])

# %%
# Scale to [0, 1]
x_train, x_valid, x_test = x_train.astype('float32') / 255 , x_valid.astype('float32') / 255, x_test.astype('float32') / 255 

# CNN need a dimension of channels
x_train = x_train.reshape(-1, 28, 28, 1)
x_valid = x_valid.reshape(-1, 28, 28, 1) 
x_test = x_test.reshape(-1, 28, 28, 1)


print(x_train.shape, x_valid.shape, x_test.shape)
print(y_train.shape, y_valid.shape, y_test.shape)
# Out:
# (50000, 28, 28, 1) (10000, 28, 28, 1) (10000, 28, 28, 1)
# (50000,) (10000,) (10000,)

# %% [markdown]
# ## Use a Sequential class

# %%
cnn = Sequential()

cnn.add(layers.Conv2D(32, 3, strides = 1, padding = 'same', activation = 'relu', input_shape=(28,28,1)))
cnn.add(layers.MaxPool2D(3, strides = 2, padding = 'same'))

cnn.add(layers.Conv2D(64, 3, strides = 1, padding = 'same', activation = 'relu'))
cnn.add(layers.MaxPool2D(3, strides = 2, padding = 'same'))
cnn.add(layers.Flatten())

cnn.add(layers.Dense(128, activation='relu'))
cnn.add(layers.Dense(10, activation='softmax'))

# %%
cnn.compile(loss = 'sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.SGD(learning_rate=0.1), metrics = ['accuracy'])

# %%
result = cnn.fit(x_train, y_train, epochs = 5, batch_size = 128, validation_data = (x_valid, y_valid))
# Out:
# Epoch 1/5
# 391/391 [==============================] - 18s 30ms/step - loss: 0.8946 - accuracy: 0.7144 - val_loss: 0.1384 - val_accuracy: 0.9550
# Epoch 2/5
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0933 - accuracy: 0.9702 - val_loss: 0.0682 - val_accuracy: 0.9797
# Epoch 3/5
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0637 - accuracy: 0.9798 - val_loss: 0.0614 - val_accuracy: 0.9801
# Epoch 4/5
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0476 - accuracy: 0.9853 - val_loss: 0.0473 - val_accuracy: 0.9855
# Epoch 5/5
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0413 - accuracy: 0.9870 - val_loss: 0.0402 - val_accuracy: 0.9887

# %%
test_result = cnn.evaluate(x_test, y_test)
print('test loss: ', test_result[0])
print('test acc: ', test_result[1])
# Out:
# 313/313 [==============================] - 4s 4ms/step - loss: 0.0350 - accuracy: 0.9883
# test loss:  0.03499814122915268
# test acc:  0.9883000254631042

# %%
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('CNN ACCURACY')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.grid()
plt.legend(['train','validation'], loc = 'best')

# %% [markdown]
# ---
# # A function for implementing training easily

# %%
data = [x_train, y_train, x_valid, y_valid, x_test, y_test]

def train(model, x_train, y_train, x_valid, y_valid, x_test, y_test, epoch = 10, lr = 0.1):
    model.compile(loss = 'sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.SGD(learning_rate=lr), metrics = ['accuracy'])
    result = model.fit(x_train, y_train, epochs = epoch, batch_size = 128, validation_data = (x_valid, y_valid))
    test_result = cnn.evaluate(x_test, y_test)

    # show the learning curve
    plt.plot(result.history['accuracy'])
    plt.plot(result.history['val_accuracy'])
    plt.title('CNN ACCURACY')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.grid()
    plt.legend(['train','validation'], loc = 'best')

# %%
train(cnn, *data, epoch=3)
# Out:
# Epoch 1/3
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0347 - accuracy: 0.9891 - val_loss: 0.0346 - val_accuracy: 0.9899
# Epoch 2/3
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0287 - accuracy: 0.9915 - val_loss: 0.0350 - val_accuracy: 0.9887
# Epoch 3/3
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0268 - accuracy: 0.9915 - val_loss: 0.0318 - val_accuracy: 0.9915
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0262 - accuracy: 0.9916

# %% [markdown]
# ## Use a Model class

# %%
class CNN(Model):
    def __init__(self):
        # CNN에서 사용하는 모든 레이어 구현 --practice p.57
        
        super(CNN, self).__init__()
        # kernel개수 32, kernel크기(3,3), strides=1 ----이미지에서 feature뽑아낸다고 이해해도 됨. 
        # conv1을 feature_extractor 이런식으로 쓰기도 함
        self.conv1 = layers.Conv2D(32,3, strides=1, padding='same', activation='relu', input_shape=(28,28,1))
        # padding에 valid나 same이나 결과 똑같은걸
        self.maxpool1 = layers.MaxPool2D(3, strides=2, padding='same')
        self.conv2 = layers.Conv2D(64, 3, strides=1, padding='same', activation='relu')
        self.maxpool2 = layers.MaxPool2D(3, strides=2, padding='same')
        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation='relu')
        self.fc2 = layers.Dense(10, activation='softmax')
          # 이런 식으로 쓰기도 한다~~
          # self.feature_extractor = Sequential()
          # self.feature_extractor.add(layers.Conv2D(32,3, strides = 1, padding='same', activation='relu'))
          # 그럼 dense layer를 classifier라고 쓴다  => 그럼 call부분이 좀 간편해짐
    
    def call(self, x):
        x = self.conv1(x)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)

        return x

# %%
cnn = CNN()
train(cnn, *data)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 19s 31ms/step - loss: 0.8553 - accuracy: 0.7334 - val_loss: 0.1027 - val_accuracy: 0.9692
# Epoch 2/10
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0967 - accuracy: 0.9688 - val_loss: 0.0759 - val_accuracy: 0.9774
# Epoch 3/10
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0660 - accuracy: 0.9796 - val_loss: 0.0645 - val_accuracy: 0.9814
# Epoch 4/10
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0516 - accuracy: 0.9845 - val_loss: 0.0491 - val_accuracy: 0.9843
# Epoch 5/10
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0392 - accuracy: 0.9878 - val_loss: 0.0404 - val_accuracy: 0.9870
# Epoch 6/10
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0335 - accuracy: 0.9892 - val_loss: 0.0468 - val_accuracy: 0.9860
# Epoch 7/10
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0316 - accuracy: 0.9901 - val_loss: 0.0438 - val_accuracy: 0.9876
# Epoch 8/10
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0254 - accuracy: 0.9923 - val_loss: 0.0382 - val_accuracy: 0.9891
# Epoch 9/10
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.0385 - val_accuracy: 0.9889
# Epoch 10/10
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0203 - accuracy: 0.9931 - val_loss: 0.0324 - val_accuracy: 0.9904
# 313/313 [==============================] - 4s 4ms/step - loss: 0.0257 - accuracy: 0.9919

# %% [markdown]
# ---
# # CIFAR-10

# %%
(x_trainval, y_trainval), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
print(type(x_trainval), x_trainval.shape)
print(type(y_trainval), y_trainval.shape)
print(type(x_test), x_test.shape)
print(type(y_test), y_test.shape)
# Out:
# <class 'numpy.ndarray'> (50000, 32, 32, 3)
# <class 'numpy.ndarray'> (50000, 1)
# <class 'numpy.ndarray'> (10000, 32, 32, 3)
# <class 'numpy.ndarray'> (10000, 1)

# %%
plt.imshow(x_trainval[10])

# %%
# Normalize to range 0 - 1
x_trainval = x_trainval.astype("float32") / 255
x_test = x_test.astype("float32") / 255

# Split train and validation dataset
x_train, x_valid, y_train, y_valid = train_test_split(x_trainval, y_trainval, test_size= 1/6, shuffle=True, stratify = y_trainval, random_state=34)

# %%
print(type(x_train), x_trainval.shape)
print(type(y_train), y_train.shape)
print(type(x_valid), x_valid.shape)
print(type(y_valid), y_valid.shape)
print(type(x_test), x_test.shape)
print(type(y_test), y_test.shape)
# Out:
# <class 'numpy.ndarray'> (50000, 32, 32, 3)
# <class 'numpy.ndarray'> (41666, 1)
# <class 'numpy.ndarray'> (8334, 32, 32, 3)
# <class 'numpy.ndarray'> (8334, 1)
# <class 'numpy.ndarray'> (10000, 32, 32, 3)
# <class 'numpy.ndarray'> (10000, 1)

# %%
#############
# Important #
#############

data = [x_train, y_train, x_valid, y_valid, x_test, y_test]

# %% [markdown]
# ---
# # CNN

# %%
class CNN(Model):
    def __init__(self):
        # CNN에서 사용하는 모든 레이어 구현 --practice p.57
        
        super(CNN, self).__init__()
        # kernel개수 32, kernel크기(3,3), strides=1 ----이미지에서 feature뽑아낸다고 이해해도 됨. 
        # conv1을 feature_extractor 이런식으로 쓰기도 함
        self.conv1 = layers.Conv2D(32,3, strides=1, padding='same', activation='relu', input_shape=(28,28,1))
        # padding에 valid나 same이나 결과 똑같은걸
        self.maxpool1 = layers.MaxPool2D(3, strides=2, padding='same')
        self.conv2 = layers.Conv2D(64, 3, strides=1, padding='same', activation='relu')
        self.maxpool2 = layers.MaxPool2D(3, strides=2, padding='same')
        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation='relu')
        self.fc2 = layers.Dense(10, activation='softmax')
          # 이런 식으로 쓰기도 한다~~
          # self.feature_extractor = Sequential()
          # self.feature_extractor.add(layers.Conv2D(32,3, strides = 1, padding='same', activation='relu'))
          # 그럼 dense layer를 classifier라고 쓴다  => 그럼 call부분이 좀 간편해짐
    
    def call(self, x):
        x = self.conv1(x)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)

        return x

# %%
cnn = CNN()
train(cnn, *data)
# mnist보다 task가 확실히 어려워져서 정확도가 떨어지게 나옴
# 모델 성능 올려주는 테크닉을 적용해야함
# Out:
# Epoch 1/10
# 326/326 [==============================] - 22s 43ms/step - loss: 2.1242 - accuracy: 0.2276 - val_loss: 1.6453 - val_accuracy: 0.4129
# Epoch 2/10
# 326/326 [==============================] - 2s 6ms/step - loss: 1.5182 - accuracy: 0.4607 - val_loss: 1.3674 - val_accuracy: 0.5058
# Epoch 3/10
# 326/326 [==============================] - 2s 6ms/step - loss: 1.2838 - accuracy: 0.5494 - val_loss: 1.2062 - val_accuracy: 0.5589
# Epoch 4/10
# 326/326 [==============================] - 2s 6ms/step - loss: 1.1234 - accuracy: 0.6063 - val_loss: 1.2176 - val_accuracy: 0.5719
# Epoch 5/10
# 326/326 [==============================] - 2s 6ms/step - loss: 0.9965 - accuracy: 0.6502 - val_loss: 1.0320 - val_accuracy: 0.6411
# Epoch 6/10
# 326/326 [==============================] - 2s 6ms/step - loss: 0.8952 - accuracy: 0.6869 - val_loss: 0.9939 - val_accuracy: 0.6493
# Epoch 7/10
# 326/326 [==============================] - 2s 6ms/step - loss: 0.8250 - accuracy: 0.7086 - val_loss: 0.9194 - val_accuracy: 0.6831
# Epoch 8/10
# 326/326 [==============================] - 2s 7ms/step - loss: 0.7418 - accuracy: 0.7420 - val_loss: 1.0192 - val_accuracy: 0.6590
# Epoch 9/10
# 326/326 [==============================] - 2s 7ms/step - loss: 0.6760 - accuracy: 0.7654 - val_loss: 0.9843 - val_accuracy: 0.6643
# Epoch 10/10
# 326/326 [==============================] - 2s 7ms/step - loss: 0.6268 - accuracy: 0.7845 - val_loss: 1.0499 - val_accuracy: 0.6603
# 313/313 [==============================] - 9s 16ms/step - loss: 1.0795 - accuracy: 0.6476

# %% [markdown]
# ---
# # Let's upgrade the network

# %% [markdown]
# ## Use more layers

# %%
class CNN(Model):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = layers.Conv2D(32, 3, strides=1, padding='same', activation='relu', input_shape=(32,32,3))
        # 전이랑 달라진거 : conv하나 더 넣음
        self.conv2 = layers.Conv2D(32, 3, strides=1, padding='same', activation='relu')
        self.maxpool1 = layers.MaxPool2D(3, strides=2, padding='same')
        self.conv3 = layers.Conv2D(64, 3, strides=1, padding='same', activation='relu')
        # 전이랑 달라진거 : conv하나 더 넣음
        self.conv4 = layers.Conv2D(64, 3, strides=1, padding='same', activation='relu')
        self.maxpool2 = layers.MaxPool2D(3, strides=2, padding='same')
        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation='relu')
        self.fc2 = layers.Dense(10, activation='softmax')
        self.relu = layers.ReLU()
        

    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.maxpool1(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)

        return x

# %%
cnn = CNN()
train(cnn, *data)
# 결과보면 큰 소득이 별로 없다고 판단을 내릴 수 있다
# 필터의 개수를 늘리거나 레이어를 추가할 수도 있는데
# 우리는 batch normalize를 해보겟다
# Out:
# Epoch 1/10
# 326/326 [==============================] - 29s 56ms/step - loss: 2.2128 - accuracy: 0.1774 - val_loss: 1.8823 - val_accuracy: 0.3234
# Epoch 2/10
# 326/326 [==============================] - 3s 10ms/step - loss: 1.7095 - accuracy: 0.3921 - val_loss: 1.4966 - val_accuracy: 0.4374
# Epoch 3/10
# 326/326 [==============================] - 3s 10ms/step - loss: 1.3620 - accuracy: 0.5118 - val_loss: 1.2711 - val_accuracy: 0.5473
# Epoch 4/10
# 326/326 [==============================] - 3s 10ms/step - loss: 1.1423 - accuracy: 0.5983 - val_loss: 1.2547 - val_accuracy: 0.5565
# Epoch 5/10
# 326/326 [==============================] - 3s 10ms/step - loss: 1.0092 - accuracy: 0.6445 - val_loss: 0.9821 - val_accuracy: 0.6447
# Epoch 6/10
# 326/326 [==============================] - 3s 10ms/step - loss: 0.8736 - accuracy: 0.6946 - val_loss: 0.8784 - val_accuracy: 0.6956
# Epoch 7/10
# 326/326 [==============================] - 3s 10ms/step - loss: 0.7785 - accuracy: 0.7277 - val_loss: 0.9137 - val_accuracy: 0.6866
# Epoch 8/10
# 326/326 [==============================] - 3s 10ms/step - loss: 0.6649 - accuracy: 0.7676 - val_loss: 0.8571 - val_accuracy: 0.7077
# Epoch 9/10
# 326/326 [==============================] - 3s 10ms/step - loss: 0.5763 - accuracy: 0.7976 - val_loss: 0.9901 - val_accuracy: 0.6829
# Epoch 10/10
# 326/326 [==============================] - 3s 10ms/step - loss: 0.4764 - accuracy: 0.8357 - val_loss: 0.9306 - val_accuracy: 0.6953
# 313/313 [==============================] - 10s 18ms/step - loss: 0.9661 - accuracy: 0.6859

# %% [markdown]
# ## Use batch normalization

# %%
class CNN(Model):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = layers.Conv2D(32, 3, strides=1, padding='same', input_shape=(32,32,3))
        # 추가된 부분
        self.bn1 = layers.BatchNormalization()
        self.maxpool1 = layers.MaxPool2D(3, strides=2, padding='same')
        self.conv2 = layers.Conv2D(64, 3, strides=1, padding='same')
        # 추가된 부분
        self.bn2 = layers.BatchNormalization()
        self.maxpool2 = layers.MaxPool2D(3, strides=2, padding='same')
        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation='relu')
        self.fc2 = layers.Dense(10, activation='softmax')
        self.relu = layers.ReLU()
        

    def call(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)

        return x

# %%
cnn = CNN()
train(cnn, *data)
# Out:
# Epoch 1/10
# 326/326 [==============================] - 3s 8ms/step - loss: 1.8333 - accuracy: 0.3585 - val_loss: 2.5011 - val_accuracy: 0.2317
# Epoch 2/10
# 326/326 [==============================] - 2s 7ms/step - loss: 1.3184 - accuracy: 0.5258 - val_loss: 1.4210 - val_accuracy: 0.5088
# Epoch 3/10
# 326/326 [==============================] - 2s 7ms/step - loss: 1.1197 - accuracy: 0.6035 - val_loss: 1.4749 - val_accuracy: 0.5059
# Epoch 4/10
# 326/326 [==============================] - 2s 7ms/step - loss: 0.9928 - accuracy: 0.6496 - val_loss: 1.2559 - val_accuracy: 0.5664
# Epoch 5/10
# 326/326 [==============================] - 2s 7ms/step - loss: 0.9131 - accuracy: 0.6809 - val_loss: 1.1988 - val_accuracy: 0.5985
# Epoch 6/10
# 326/326 [==============================] - 2s 7ms/step - loss: 0.8380 - accuracy: 0.7075 - val_loss: 1.8847 - val_accuracy: 0.4471
# Epoch 7/10
# 326/326 [==============================] - 2s 7ms/step - loss: 0.7755 - accuracy: 0.7293 - val_loss: 1.3341 - val_accuracy: 0.5642
# Epoch 8/10
# 326/326 [==============================] - 2s 7ms/step - loss: 0.7166 - accuracy: 0.7491 - val_loss: 1.0360 - val_accuracy: 0.6479
# Epoch 9/10
# 326/326 [==============================] - 2s 7ms/step - loss: 0.6637 - accuracy: 0.7692 - val_loss: 0.9770 - val_accuracy: 0.6677
# Epoch 10/10
# 326/326 [==============================] - 2s 7ms/step - loss: 0.6163 - accuracy: 0.7853 - val_loss: 1.1481 - val_accuracy: 0.6350
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1601 - accuracy: 0.6339

# %% [markdown]
# ---
# # Make Network more easily - use a function

# %%
def make_conv_block(num_filters, filter_size, stride, padding='same', input_shape=None):
    conv_block = tf.keras.Sequential()
    if input_shape is not None:
        conv_block.add(layers.Conv2D(num_filters, filter_size, strides=stride, padding=padding, input_shape=input_shape))
    
    conv_block.add(layers.Conv2D(num_filters, filter_size, strides=stride, padding=padding))
    conv_block.add(layers.BatchNormalization())
    conv_block.add(layers.ReLU())
    return conv_block

# %%
class CNN(Model):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = make_conv_block(32, 3, 1, 'same', (32, 32, 3))
        self.conv2 = make_conv_block(32, 3, 1, 'same')
        self.maxpool1 = layers.MaxPool2D(3, strides=2, padding='same')

        self.conv3 = make_conv_block(64, 3, 1, 'same')
        self.conv4 = make_conv_block(64, 3, 1, 'same')
        self.maxpool2 = layers.MaxPool2D(3, strides=2, padding='same')

        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation='relu')
        self.fc2 = layers.Dense(10, activation='softmax')
        self.relu = layers.ReLU()
        

    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.maxpool1(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)

        return x

# %%
cnn = CNN()
train(cnn, *data)
# Out:
# Epoch 1/10
# 326/326 [==============================] - 34s 74ms/step - loss: 3.4519 - accuracy: 0.2587 - val_loss: 2.0481 - val_accuracy: 0.3138
# Epoch 2/10
# 326/326 [==============================] - 4s 14ms/step - loss: 1.4363 - accuracy: 0.4756 - val_loss: 1.4170 - val_accuracy: 0.4885
# Epoch 3/10
# 326/326 [==============================] - 5s 14ms/step - loss: 1.1463 - accuracy: 0.5891 - val_loss: 1.4338 - val_accuracy: 0.5293
# Epoch 4/10
# 326/326 [==============================] - 5s 14ms/step - loss: 0.9659 - accuracy: 0.6569 - val_loss: 1.1918 - val_accuracy: 0.5946
# Epoch 5/10
# 326/326 [==============================] - 5s 14ms/step - loss: 0.8515 - accuracy: 0.6980 - val_loss: 0.9253 - val_accuracy: 0.6775
# Epoch 6/10
# 326/326 [==============================] - 5s 14ms/step - loss: 0.7488 - accuracy: 0.7393 - val_loss: 0.9262 - val_accuracy: 0.6728
# Epoch 7/10
# 326/326 [==============================] - 5s 14ms/step - loss: 0.6662 - accuracy: 0.7673 - val_loss: 0.9288 - val_accuracy: 0.6848
# Epoch 8/10
# 326/326 [==============================] - 5s 14ms/step - loss: 0.6110 - accuracy: 0.7855 - val_loss: 1.2650 - val_accuracy: 0.6034
# Epoch 9/10
# 326/326 [==============================] - 5s 14ms/step - loss: 0.5567 - accuracy: 0.8080 - val_loss: 0.8399 - val_accuracy: 0.7196
# Epoch 10/10
# 326/326 [==============================] - 5s 14ms/step - loss: 0.5032 - accuracy: 0.8247 - val_loss: 0.6876 - val_accuracy: 0.7665
# 313/313 [==============================] - 21s 36ms/step - loss: 0.6913 - accuracy: 0.7642

# %% [markdown]
# ---
# # Make Network more easily - use a custom layer

# %%
class ConvBlock(layers.Layer):
    def __init__(self, num_filters, filter_size, stride, padding='same', input_shape=None):
        super(ConvBlock, self).__init__()
        if input_shape is not None:
            self.conv = layers.Conv2D(num_filters, filter_size, strides = stride, padding=padding, input_shape=input_shape)
        else:
            self.conv = layers.Conv2D(num_filters, filter_size, strides=stride, padding=padding)
        self.bn = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        
        return x

# %%
class CNN(Model):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = ConvBlock(32, 3, 1, 'same', (32, 32, 3))
        self.conv2 = ConvBlock(32, 3, 1, 'same')
        self.maxpool1 = layers.MaxPool2D(3, strides=2, padding='same')

        self.conv3 = ConvBlock(64, 3, 1, 'same')
        self.conv4 = ConvBlock(64, 3, 1, 'same')
        self.maxpool2 = layers.MaxPool2D(3, strides=2, padding='same')

        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation='relu')
        self.fc2 = layers.Dense(10, activation='softmax')
        self.relu = layers.ReLU()
        

    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.maxpool1(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)

        return x

# %%
cnn = CNN()
train(cnn, *data)
# Out:
# Epoch 1/10
# 326/326 [==============================] - 5s 14ms/step - loss: 4.2912 - accuracy: 0.2916 - val_loss: 1.4966 - val_accuracy: 0.4659
# Epoch 2/10
# 326/326 [==============================] - 4s 12ms/step - loss: 1.3527 - accuracy: 0.5070 - val_loss: 1.2156 - val_accuracy: 0.5592
# Epoch 3/10
# 326/326 [==============================] - 4s 12ms/step - loss: 1.0985 - accuracy: 0.6073 - val_loss: 1.2977 - val_accuracy: 0.5628
# Epoch 4/10
# 326/326 [==============================] - 4s 12ms/step - loss: 0.9481 - accuracy: 0.6664 - val_loss: 1.5487 - val_accuracy: 0.4867
# Epoch 5/10
# 326/326 [==============================] - 4s 12ms/step - loss: 0.8342 - accuracy: 0.7058 - val_loss: 1.0858 - val_accuracy: 0.6256
# Epoch 6/10
# 326/326 [==============================] - 4s 12ms/step - loss: 0.7402 - accuracy: 0.7389 - val_loss: 1.0612 - val_accuracy: 0.6451
# Epoch 7/10
# 326/326 [==============================] - 4s 12ms/step - loss: 0.6746 - accuracy: 0.7658 - val_loss: 0.8756 - val_accuracy: 0.6925
# Epoch 8/10
# 326/326 [==============================] - 4s 12ms/step - loss: 0.6124 - accuracy: 0.7860 - val_loss: 0.9610 - val_accuracy: 0.6777
# Epoch 9/10
# 326/326 [==============================] - 4s 12ms/step - loss: 0.5551 - accuracy: 0.8041 - val_loss: 1.3816 - val_accuracy: 0.6106
# Epoch 10/10
# 326/326 [==============================] - 4s 12ms/step - loss: 0.5089 - accuracy: 0.8220 - val_loss: 0.7821 - val_accuracy: 0.7309
# 313/313 [==============================] - 2s 5ms/step - loss: 0.8033 - accuracy: 0.7238

# %% [markdown]
# 요즘 사용하는건 많이 깊다!! 근데 resnet같은 경우는 추가적인 연결이 있다. residual connection이라고 잇당
#
# 이러한 코드를 구현하기 위해서는 복잡스 하다
#
# 그래서 부분단위를 우리가 구현한 class나 function을 이용해서 구현한다.
#
#
#
# 그런걸 더 하고 싶다고 하면
#
# github에서 예시로 볼 수 잇는 코드 많다
#
#
# keras-resnet 이라고 쳐봐라
#
# 코드를 보면
#
# block이런게 잇는데 아마 우리가 만든거랑 비슷한 형태일거임
